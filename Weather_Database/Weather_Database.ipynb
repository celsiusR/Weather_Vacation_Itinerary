# %%
# Import the dependencies.
import pandas as pd
import json
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the requests library.
import requests

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 758

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=C4a13537cedb7d1a040f63c5a2f30a93

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")


# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):
   
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(10)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
                 
        # Convert the date to ISO standard.
       # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                         # "Date": city_date,
                        "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | yellowknife
# Processing Record 2 of Set 1 | alyangula
# Processing Record 3 of Set 1 | kodiak
# Processing Record 4 of Set 1 | nikolskoye
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | iquique
# Processing Record 8 of Set 1 | cherskiy
# Processing Record 9 of Set 1 | jamestown
# Processing Record 10 of Set 1 | snezhnogorsk
# Processing Record 11 of Set 1 | san patricio
# Processing Record 12 of Set 1 | tuatapere
# Processing Record 13 of Set 1 | les cayes
# Processing Record 14 of Set 1 | prainha
# Processing Record 15 of Set 1 | yavatmal
# Processing Record 16 of Set 1 | hobart
# Processing Record 17 of Set 1 | kailua
# Processing Record 18 of Set 1 | orocue
# Processing Record 19 of Set 1 | csurgo
# Processing Record 20 of Set 1 | khatanga
# Processing Record 21 of Set 1 | hilo
# Processing Record 22 of Set 1 | carnarvon
# Processing Record 23 of Set 1 | kalabo
# Processing Record 24 of Set 1 | victoria
# Processing Record 25 of Set 1 | evensk
# Processing Record 26 of Set 1 | hithadhoo
# Processing Record 27 of Set 1 | haines junction
# Processing Record 28 of Set 1 | vaitape
# Processing Record 29 of Set 1 | porto belo
# Processing Record 30 of Set 1 | liwale
# Processing Record 31 of Set 1 | port alfred
# Processing Record 32 of Set 1 | severo-kurilsk
# Processing Record 33 of Set 1 | plettenberg bay
# Processing Record 34 of Set 1 | villa maria
# Processing Record 35 of Set 1 | upernavik
# Processing Record 36 of Set 1 | rikitea
# Processing Record 37 of Set 1 | talnakh
# Processing Record 38 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 1 | tiksi
# Processing Record 40 of Set 1 | panaba
# Processing Record 41 of Set 1 | zwedru
# Processing Record 42 of Set 1 | richards bay
# Processing Record 43 of Set 1 | cidreira
# Processing Record 44 of Set 1 | kavaratti
# Processing Record 45 of Set 1 | portland
# Processing Record 46 of Set 1 | busselton
# Processing Record 47 of Set 1 | georgetown
# Processing Record 48 of Set 1 | korla
# Processing Record 49 of Set 1 | qaanaaq
# Processing Record 50 of Set 1 | xai-xai
# Processing Record 1 of Set 2 | mackay
# Processing Record 2 of Set 2 | bluff
# Processing Record 3 of Set 2 | vaini
# Processing Record 4 of Set 2 | dikson
# Processing Record 5 of Set 2 | ushuaia
# Processing Record 6 of Set 2 | souillac
# Processing Record 7 of Set 2 | marche-en-famenne
# Processing Record 8 of Set 2 | airai
# Processing Record 9 of Set 2 | ouadda
# Processing Record 10 of Set 2 | bilma
# Processing Record 11 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 2 | thunder bay
# Processing Record 13 of Set 2 | asau
# Processing Record 14 of Set 2 | coquimbo
# Processing Record 15 of Set 2 | chuy
# Processing Record 16 of Set 2 | kwinana
# Processing Record 17 of Set 2 | nisporeni
# Processing Record 18 of Set 2 | shangrao
# Processing Record 19 of Set 2 | ponta do sol
# Processing Record 20 of Set 2 | port hardy
# Processing Record 21 of Set 2 | sitionuevo
# Processing Record 22 of Set 2 | rolim de moura
# City not found. Skipping...
# Processing Record 23 of Set 2 | luebo
# Processing Record 24 of Set 2 | dzhusaly
# City not found. Skipping...
# Processing Record 25 of Set 2 | lebu
# Processing Record 26 of Set 2 | solnechnyy
# Processing Record 27 of Set 2 | simi
# Processing Record 28 of Set 2 | east london
# Processing Record 29 of Set 2 | narsaq
# Processing Record 30 of Set 2 | turukhansk
# Processing Record 31 of Set 2 | lasa
# Processing Record 32 of Set 2 | xuanhua
# Processing Record 33 of Set 2 | saint-philippe
# Processing Record 34 of Set 2 | mataura
# Processing Record 35 of Set 2 | laguna
# Processing Record 36 of Set 2 | moundsville
# Processing Record 37 of Set 2 | avarua
# Processing Record 38 of Set 2 | a coruna
# Processing Record 39 of Set 2 | sabang
# Processing Record 40 of Set 2 | shimsk
# Processing Record 41 of Set 2 | shieli
# Processing Record 42 of Set 2 | coahuayana
# Processing Record 43 of Set 2 | karauzyak
# City not found. Skipping...
# Processing Record 44 of Set 2 | constantine
# Processing Record 45 of Set 2 | nioro
# Processing Record 46 of Set 2 | peniche
# Processing Record 47 of Set 2 | port moresby
# Processing Record 48 of Set 2 | bethel
# Processing Record 49 of Set 2 | anda
# Processing Record 50 of Set 2 | camana
# Processing Record 1 of Set 3 | bathsheba
# Processing Record 2 of Set 3 | yenagoa
# Processing Record 3 of Set 3 | ocos
# Processing Record 4 of Set 3 | beyneu
# Processing Record 5 of Set 3 | broome
# Processing Record 6 of Set 3 | kapaa
# Processing Record 7 of Set 3 | surt
# Processing Record 8 of Set 3 | katsuura
# Processing Record 9 of Set 3 | port elizabeth
# Processing Record 10 of Set 3 | othonoi
# City not found. Skipping...
# Processing Record 11 of Set 3 | butaritari
# Processing Record 12 of Set 3 | tura
# Processing Record 13 of Set 3 | kikwit
# Processing Record 14 of Set 3 | lagoa
# Processing Record 15 of Set 3 | tampere
# Processing Record 16 of Set 3 | cape town
# Processing Record 17 of Set 3 | iqaluit
# Processing Record 18 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 3 | castro
# Processing Record 20 of Set 3 | thompson
# Processing Record 21 of Set 3 | kindu
# Processing Record 22 of Set 3 | nantucket
# Processing Record 23 of Set 3 | werda
# Processing Record 24 of Set 3 | road town
# Processing Record 25 of Set 3 | mehamn
# Processing Record 26 of Set 3 | wasilla
# Processing Record 27 of Set 3 | leningradskiy
# Processing Record 28 of Set 3 | la ronge
# Processing Record 29 of Set 3 | los llanos de aridane
# Processing Record 30 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 3 | faya
# Processing Record 32 of Set 3 | saskylakh
# Processing Record 33 of Set 3 | pisco
# Processing Record 34 of Set 3 | collie
# Processing Record 35 of Set 3 | pevek
# Processing Record 36 of Set 3 | hermanus
# Processing Record 37 of Set 3 | tamandare
# Processing Record 38 of Set 3 | bay roberts
# Processing Record 39 of Set 3 | chokurdakh
# Processing Record 40 of Set 3 | manaus
# Processing Record 41 of Set 3 | tessalit
# Processing Record 42 of Set 3 | high prairie
# Processing Record 43 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 3 | thurso
# Processing Record 45 of Set 3 | namatanai
# Processing Record 46 of Set 3 | hami
# Processing Record 47 of Set 3 | tuktoyaktuk
# Processing Record 48 of Set 3 | omboue
# Processing Record 49 of Set 3 | zharkent
# Processing Record 50 of Set 3 | aswan
# Processing Record 1 of Set 4 | shu
# Processing Record 2 of Set 4 | barrow
# Processing Record 3 of Set 4 | khorixas
# Processing Record 4 of Set 4 | mangai
# Processing Record 5 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 4 | dakar
# Processing Record 7 of Set 4 | qasigiannguit
# Processing Record 8 of Set 4 | kurilsk
# Processing Record 9 of Set 4 | acarau
# Processing Record 10 of Set 4 | saldanha
# Processing Record 11 of Set 4 | delhi
# Processing Record 12 of Set 4 | cayenne
# Processing Record 13 of Set 4 | tezu
# Processing Record 14 of Set 4 | bilibino
# Processing Record 15 of Set 4 | itoman
# Processing Record 16 of Set 4 | kysyl-syr
# Processing Record 17 of Set 4 | yulara
# Processing Record 18 of Set 4 | key west
# Processing Record 19 of Set 4 | robertsport
# Processing Record 20 of Set 4 | nanortalik
# Processing Record 21 of Set 4 | camacha
# Processing Record 22 of Set 4 | rudnaya pristan
# Processing Record 23 of Set 4 | vanimo
# Processing Record 24 of Set 4 | san cristobal
# Processing Record 25 of Set 4 | matamoros
# Processing Record 26 of Set 4 | saint george
# Processing Record 27 of Set 4 | labuhan
# Processing Record 28 of Set 4 | gaoual
# Processing Record 29 of Set 4 | cap malheureux
# Processing Record 30 of Set 4 | cabo san lucas
# Processing Record 31 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 4 | kaitangata
# Processing Record 33 of Set 4 | bredasdorp
# Processing Record 34 of Set 4 | shingu
# Processing Record 35 of Set 4 | amga
# Processing Record 36 of Set 4 | krasnoselkup
# Processing Record 37 of Set 4 | dillon
# Processing Record 38 of Set 4 | mar del plata
# Processing Record 39 of Set 4 | venado tuerto
# Processing Record 40 of Set 4 | ahipara
# Processing Record 41 of Set 4 | inhambane
# Processing Record 42 of Set 4 | terrace bay
# Processing Record 43 of Set 4 | suba
# Processing Record 44 of Set 4 | port blair
# Processing Record 45 of Set 4 | oktyabrskiy
# Processing Record 46 of Set 4 | north bend
# Processing Record 47 of Set 4 | pangody
# Processing Record 48 of Set 4 | tynda
# Processing Record 49 of Set 4 | filingue
# Processing Record 50 of Set 4 | samarkand
# Processing Record 1 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 5 | belyy yar
# Processing Record 3 of Set 5 | mahebourg
# Processing Record 4 of Set 5 | mount isa
# Processing Record 5 of Set 5 | tabuk
# Processing Record 6 of Set 5 | tommot
# Processing Record 7 of Set 5 | tasbuget
# City not found. Skipping...
# Processing Record 8 of Set 5 | lorengau
# Processing Record 9 of Set 5 | oranjestad
# Processing Record 10 of Set 5 | zaraza
# Processing Record 11 of Set 5 | kruisfontein
# Processing Record 12 of Set 5 | guerrero negro
# Processing Record 13 of Set 5 | izumo
# Processing Record 14 of Set 5 | makushino
# Processing Record 15 of Set 5 | madang
# Processing Record 16 of Set 5 | kolvereid
# Processing Record 17 of Set 5 | ostrovnoy
# Processing Record 18 of Set 5 | bambous virieux
# Processing Record 19 of Set 5 | caraquet
# Processing Record 20 of Set 5 | erenhot
# Processing Record 21 of Set 5 | gornopravdinsk
# Processing Record 22 of Set 5 | norman wells
# Processing Record 23 of Set 5 | santa isabel do rio negro
# Processing Record 24 of Set 5 | hamilton
# Processing Record 25 of Set 5 | shelburne
# Processing Record 26 of Set 5 | ketchikan
# Processing Record 27 of Set 5 | atuona
# Processing Record 28 of Set 5 | saint-augustin
# Processing Record 29 of Set 5 | chabahar
# Processing Record 30 of Set 5 | matadi
# Processing Record 31 of Set 5 | new norfolk
# Processing Record 32 of Set 5 | arraial do cabo
# Processing Record 33 of Set 5 | husavik
# Processing Record 34 of Set 5 | padang
# Processing Record 35 of Set 5 | hasaki
# Processing Record 36 of Set 5 | alice springs
# Processing Record 37 of Set 5 | kahului
# Processing Record 38 of Set 5 | antsohihy
# Processing Record 39 of Set 5 | lompoc
# Processing Record 40 of Set 5 | kamenka
# Processing Record 41 of Set 5 | cobija
# Processing Record 42 of Set 5 | torbay
# Processing Record 43 of Set 5 | chimbote
# Processing Record 44 of Set 5 | clyde river
# Processing Record 45 of Set 5 | killybegs
# Processing Record 46 of Set 5 | sao joao da barra
# Processing Record 47 of Set 5 | taoudenni
# Processing Record 48 of Set 5 | savinka
# Processing Record 49 of Set 5 | micheweni
# Processing Record 50 of Set 5 | dingle
# Processing Record 1 of Set 6 | burica
# City not found. Skipping...
# Processing Record 2 of Set 6 | sao filipe
# Processing Record 3 of Set 6 | dalianwan
# Processing Record 4 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 6 | sitrah
# Processing Record 7 of Set 6 | casino
# Processing Record 8 of Set 6 | caravelas
# Processing Record 9 of Set 6 | yanaul
# Processing Record 10 of Set 6 | matata
# Processing Record 11 of Set 6 | shiyan
# Processing Record 12 of Set 6 | longyearbyen
# Processing Record 13 of Set 6 | batagay-alyta
# Processing Record 14 of Set 6 | cabedelo
# Processing Record 15 of Set 6 | grandview
# Processing Record 16 of Set 6 | klaksvik
# Processing Record 17 of Set 6 | touros
# Processing Record 18 of Set 6 | ladario
# Processing Record 19 of Set 6 | kavieng
# Processing Record 20 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 6 | te anau
# Processing Record 22 of Set 6 | omsukchan
# Processing Record 23 of Set 6 | albion
# Processing Record 24 of Set 6 | marzuq
# Processing Record 25 of Set 6 | waiuku
# Processing Record 26 of Set 6 | sychevka
# Processing Record 27 of Set 6 | margate
# Processing Record 28 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 6 | goundam
# Processing Record 30 of Set 6 | flinders
# Processing Record 31 of Set 6 | balkanabat
# Processing Record 32 of Set 6 | rafaela
# Processing Record 33 of Set 6 | fort nelson
# Processing Record 34 of Set 6 | winnemucca
# Processing Record 35 of Set 6 | fuerte
# Processing Record 36 of Set 6 | varkaus
# Processing Record 37 of Set 6 | comodoro rivadavia
# Processing Record 38 of Set 6 | prince rupert
# Processing Record 39 of Set 6 | tasiilaq
# Processing Record 40 of Set 6 | kashan
# Processing Record 41 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 42 of Set 6 | camabatela
# Processing Record 43 of Set 6 | abha
# Processing Record 44 of Set 6 | blonduos
# City not found. Skipping...
# Processing Record 45 of Set 6 | harper
# Processing Record 46 of Set 6 | redmond
# Processing Record 47 of Set 6 | hirara
# Processing Record 48 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 6 | boguchany
# Processing Record 50 of Set 6 | esperance
# Processing Record 1 of Set 7 | namie
# Processing Record 2 of Set 7 | puerto leguizamo
# Processing Record 3 of Set 7 | beira
# Processing Record 4 of Set 7 | bengkulu
# Processing Record 5 of Set 7 | ballina
# Processing Record 6 of Set 7 | codrington
# Processing Record 7 of Set 7 | mareeba
# Processing Record 8 of Set 7 | estelle
# Processing Record 9 of Set 7 | north platte
# Processing Record 10 of Set 7 | takhtamygda
# Processing Record 11 of Set 7 | gazojak
# Processing Record 12 of Set 7 | campbellton
# Processing Record 13 of Set 7 | satinka
# Processing Record 14 of Set 7 | biak
# Processing Record 15 of Set 7 | the woodlands
# Processing Record 16 of Set 7 | asfi
# Processing Record 17 of Set 7 | ulaangom
# Processing Record 18 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 19 of Set 7 | grindavik
# Processing Record 20 of Set 7 | axim
# Processing Record 21 of Set 7 | abu jubayhah
# City not found. Skipping...
# Processing Record 22 of Set 7 | puerto ayora
# Processing Record 23 of Set 7 | lata
# Processing Record 24 of Set 7 | constitucion
# Processing Record 25 of Set 7 | tucuman
# Processing Record 26 of Set 7 | ribeira grande
# Processing Record 27 of Set 7 | rypefjord
# Processing Record 28 of Set 7 | talas
# Processing Record 29 of Set 7 | geraldton
# Processing Record 30 of Set 7 | yirol
# City not found. Skipping...
# Processing Record 31 of Set 7 | grand-santi
# Processing Record 32 of Set 7 | kaeo
# Processing Record 33 of Set 7 | kidodi
# Processing Record 34 of Set 7 | havre-saint-pierre
# Processing Record 35 of Set 7 | onega
# Processing Record 36 of Set 7 | basco
# Processing Record 37 of Set 7 | nettuno
# Processing Record 38 of Set 7 | provideniya
# Processing Record 39 of Set 7 | ucluelet
# Processing Record 40 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 41 of Set 7 | egvekinot
# Processing Record 42 of Set 7 | nome
# Processing Record 43 of Set 7 | solsvik
# City not found. Skipping...
# Processing Record 44 of Set 7 | hunza
# City not found. Skipping...
# Processing Record 45 of Set 7 | macenta
# Processing Record 46 of Set 7 | broken hill
# Processing Record 47 of Set 7 | hwange
# Processing Record 48 of Set 7 | hambantota
# Processing Record 49 of Set 7 | kargat
# Processing Record 50 of Set 7 | palmer
# Processing Record 1 of Set 8 | trincomalee
# Processing Record 2 of Set 8 | loukhi
# Processing Record 3 of Set 8 | viedma
# Processing Record 4 of Set 8 | churapcha
# Processing Record 5 of Set 8 | bambanglipuro
# Processing Record 6 of Set 8 | paamiut
# Processing Record 7 of Set 8 | kazachinskoye
# Processing Record 8 of Set 8 | tiarei
# Processing Record 9 of Set 8 | kargopol
# Processing Record 10 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 8 | yunhe
# Processing Record 12 of Set 8 | rawlins
# Processing Record 13 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 14 of Set 8 | santa maria
# Processing Record 15 of Set 8 | pekalongan
# Processing Record 16 of Set 8 | ouesso
# Processing Record 17 of Set 8 | meulaboh
# Processing Record 18 of Set 8 | avera
# Processing Record 19 of Set 8 | pangnirtung
# Processing Record 20 of Set 8 | grand gaube
# Processing Record 21 of Set 8 | paka
# Processing Record 22 of Set 8 | terekli-mekteb
# Processing Record 23 of Set 8 | karratha
# Processing Record 24 of Set 8 | coromandel
# Processing Record 25 of Set 8 | karakendzha
# City not found. Skipping...
# Processing Record 26 of Set 8 | hofn
# Processing Record 27 of Set 8 | honningsvag
# Processing Record 28 of Set 8 | dudinka
# Processing Record 29 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 8 | yar-sale
# Processing Record 31 of Set 8 | paraiso
# Processing Record 32 of Set 8 | resistencia
# Processing Record 33 of Set 8 | sisimiut
# Processing Record 34 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 35 of Set 8 | olafsvik
# Processing Record 36 of Set 8 | uhlove
# Processing Record 37 of Set 8 | srednekolymsk
# Processing Record 38 of Set 8 | valleyview
# Processing Record 39 of Set 8 | henties bay
# Processing Record 40 of Set 8 | fairbanks
# Processing Record 41 of Set 8 | opuwo
# Processing Record 42 of Set 8 | wad madani
# Processing Record 43 of Set 8 | sala
# Processing Record 44 of Set 8 | isangel
# Processing Record 45 of Set 8 | iwanai
# Processing Record 46 of Set 8 | wangqing
# Processing Record 47 of Set 8 | bulgan
# Processing Record 48 of Set 8 | verkhnyaya toyma
# Processing Record 49 of Set 8 | bemidji
# Processing Record 50 of Set 8 | kiunga
# Processing Record 1 of Set 9 | bandarbeyla
# Processing Record 2 of Set 9 | dawson creek
# Processing Record 3 of Set 9 | faanui
# Processing Record 4 of Set 9 | toba
# Processing Record 5 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 6 of Set 9 | baruun-urt
# Processing Record 7 of Set 9 | sosnovo-ozerskoye
# Processing Record 8 of Set 9 | coihaique
# Processing Record 9 of Set 9 | ribeira brava
# Processing Record 10 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 11 of Set 9 | abalak
# Processing Record 12 of Set 9 | mao
# Processing Record 13 of Set 9 | vostok
# Processing Record 14 of Set 9 | port pirie
# Processing Record 15 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 16 of Set 9 | izazi
# Processing Record 17 of Set 9 | mayo
# Processing Record 18 of Set 9 | englehart
# Processing Record 19 of Set 9 | nabire
# Processing Record 20 of Set 9 | xining
# Processing Record 21 of Set 9 | lingao
# Processing Record 22 of Set 9 | annau
# Processing Record 23 of Set 9 | akdagmadeni
# Processing Record 24 of Set 9 | grasse
# Processing Record 25 of Set 9 | abu dhabi
# Processing Record 26 of Set 9 | yekaterinovka
# Processing Record 27 of Set 9 | hovd
# Processing Record 28 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 29 of Set 9 | naze
# Processing Record 30 of Set 9 | salalah
# Processing Record 31 of Set 9 | kieta
# Processing Record 32 of Set 9 | cabo rojo
# Processing Record 33 of Set 9 | namibe
# Processing Record 34 of Set 9 | zhanaozen
# Processing Record 35 of Set 9 | mantua
# Processing Record 36 of Set 9 | le port
# Processing Record 37 of Set 9 | nyurba
# Processing Record 38 of Set 9 | durazno
# Processing Record 39 of Set 9 | chernyshevskiy
# Processing Record 40 of Set 9 | hervey bay
# Processing Record 41 of Set 9 | uberlandia
# Processing Record 42 of Set 9 | luganville
# Processing Record 43 of Set 9 | glasgow
# Processing Record 44 of Set 9 | kirakira
# Processing Record 45 of Set 9 | nacala
# Processing Record 46 of Set 9 | kununurra
# Processing Record 47 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 9 | qaqortoq
# Processing Record 49 of Set 9 | kainantu
# Processing Record 50 of Set 9 | kushima
# Processing Record 1 of Set 10 | vao
# Processing Record 2 of Set 10 | ambon
# Processing Record 3 of Set 10 | pompeu
# Processing Record 4 of Set 10 | balaipungut
# Processing Record 5 of Set 10 | luderitz
# Processing Record 6 of Set 10 | half moon bay
# Processing Record 7 of Set 10 | esso
# Processing Record 8 of Set 10 | christchurch
# Processing Record 9 of Set 10 | miraflores
# Processing Record 10 of Set 10 | sembe
# Processing Record 11 of Set 10 | pasighat
# Processing Record 12 of Set 10 | minas
# Processing Record 13 of Set 10 | vardo
# Processing Record 14 of Set 10 | la concepcion
# Processing Record 15 of Set 10 | ellisras
# Processing Record 16 of Set 10 | santa cruz
# Processing Record 17 of Set 10 | lira
# Processing Record 18 of Set 10 | prince george
# Processing Record 19 of Set 10 | bonthe
# Processing Record 20 of Set 10 | drayton valley
# Processing Record 21 of Set 10 | bria
# Processing Record 22 of Set 10 | mugur-aksy
# Processing Record 23 of Set 10 | port lincoln
# Processing Record 24 of Set 10 | zabid
# Processing Record 25 of Set 10 | bull savanna
# Processing Record 26 of Set 10 | wladyslawowo
# Processing Record 27 of Set 10 | tuggurt
# City not found. Skipping...
# Processing Record 28 of Set 10 | valkeala
# Processing Record 29 of Set 10 | nelson bay
# Processing Record 30 of Set 10 | buraydah
# Processing Record 31 of Set 10 | gamba
# Processing Record 32 of Set 10 | maraba
# Processing Record 33 of Set 10 | santa rosa
# Processing Record 34 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 35 of Set 10 | bafata
# Processing Record 36 of Set 10 | tabas
# Processing Record 37 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 38 of Set 10 | inongo
# Processing Record 39 of Set 10 | natal
# Processing Record 40 of Set 10 | poya
# Processing Record 41 of Set 10 | aklavik
# Processing Record 42 of Set 10 | sahagun
# Processing Record 43 of Set 10 | sitka
# Processing Record 44 of Set 10 | killam
# Processing Record 45 of Set 10 | shumskiy
# Processing Record 46 of Set 10 | beringovskiy
# Processing Record 47 of Set 10 | sumenep
# Processing Record 48 of Set 10 | san ramon
# Processing Record 49 of Set 10 | byron bay
# Processing Record 50 of Set 10 | inirida
# Processing Record 1 of Set 11 | hendrina
# Processing Record 2 of Set 11 | vila velha
# Processing Record 3 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 11 | detva
# Processing Record 5 of Set 11 | gravdal
# Processing Record 6 of Set 11 | lavrentiya
# Processing Record 7 of Set 11 | brewster
# Processing Record 8 of Set 11 | ontario
# Processing Record 9 of Set 11 | kondopoga
# Processing Record 10 of Set 11 | chicama
# Processing Record 11 of Set 11 | mocuba
# Processing Record 12 of Set 11 | kilimatinde
# Processing Record 13 of Set 11 | mouzakion
# City not found. Skipping...
# Processing Record 14 of Set 11 | manggar
# Processing Record 15 of Set 11 | kathmandu
# Processing Record 16 of Set 11 | begoro
# Processing Record 17 of Set 11 | grand-lahou
# Processing Record 18 of Set 11 | arman
# Processing Record 19 of Set 11 | ilulissat
# Processing Record 20 of Set 11 | antalaha
# Processing Record 21 of Set 11 | soeng sang
# Processing Record 22 of Set 11 | warmbad
# Processing Record 23 of Set 11 | itarema
# Processing Record 24 of Set 11 | gaziantep
# Processing Record 25 of Set 11 | westport
# Processing Record 26 of Set 11 | esperantinopolis
# Processing Record 27 of Set 11 | nouadhibou
# Processing Record 28 of Set 11 | petatlan
# Processing Record 29 of Set 11 | buchanan
# Processing Record 30 of Set 11 | marrakesh
# Processing Record 31 of Set 11 | araouane
# Processing Record 32 of Set 11 | bolshiye uki
# City not found. Skipping...
# Processing Record 33 of Set 11 | fortuna
# Processing Record 34 of Set 11 | saint anthony
# Processing Record 35 of Set 11 | forestville
# Processing Record 36 of Set 11 | skotterud
# Processing Record 37 of Set 11 | kotido
# Processing Record 38 of Set 11 | elko
# Processing Record 39 of Set 11 | sao paulo de olivenca
# Processing Record 40 of Set 11 | raudeberg
# Processing Record 41 of Set 11 | alofi
# Processing Record 42 of Set 11 | caarapo
# Processing Record 43 of Set 11 | tigre
# Processing Record 44 of Set 11 | borujan
# City not found. Skipping...
# Processing Record 45 of Set 11 | sept-iles
# Processing Record 46 of Set 11 | namtsy
# Processing Record 47 of Set 11 | kyra
# Processing Record 48 of Set 11 | ancud
# Processing Record 49 of Set 11 | duz
# City not found. Skipping...
# Processing Record 50 of Set 11 | sawtell
# Processing Record 1 of Set 12 | dalen
# Processing Record 2 of Set 12 | porto novo
# Processing Record 3 of Set 12 | agirish
# Processing Record 4 of Set 12 | olivenca
# Processing Record 5 of Set 12 | diplo
# Processing Record 6 of Set 12 | bubaque
# Processing Record 7 of Set 12 | sovetskiy
# Processing Record 8 of Set 12 | boa vista
# Processing Record 9 of Set 12 | muyinga
# Processing Record 10 of Set 12 | innisfail
# Processing Record 11 of Set 12 | antofagasta
# Processing Record 12 of Set 12 | buta
# Processing Record 13 of Set 12 | sayyan
# Processing Record 14 of Set 12 | stephenville
# Processing Record 15 of Set 12 | twin falls
# Processing Record 16 of Set 12 | yanan
# City not found. Skipping...
# Processing Record 17 of Set 12 | nalut
# Processing Record 18 of Set 12 | hoa binh
# Processing Record 19 of Set 12 | teya
# Processing Record 20 of Set 12 | konongo
# Processing Record 21 of Set 12 | paracatu
# Processing Record 22 of Set 12 | lazaro cardenas
# Processing Record 23 of Set 12 | muswellbrook
# Processing Record 24 of Set 12 | pilao arcado
# City not found. Skipping...
# Processing Record 25 of Set 12 | tema
# Processing Record 26 of Set 12 | mecca
# Processing Record 27 of Set 12 | noumea
# Processing Record 28 of Set 12 | soria
# Processing Record 29 of Set 12 | mtama
# Processing Record 30 of Set 12 | skjervoy
# Processing Record 31 of Set 12 | northam
# Processing Record 32 of Set 12 | tocopilla
# Processing Record 33 of Set 12 | teseney
# Processing Record 34 of Set 12 | sorong
# Processing Record 35 of Set 12 | sur
# Processing Record 36 of Set 12 | eustis
# Processing Record 37 of Set 12 | guymon
# Processing Record 38 of Set 12 | nouakchott
# Processing Record 39 of Set 12 | celestun
# Processing Record 40 of Set 12 | maragua
# Processing Record 41 of Set 12 | port hedland
# Processing Record 42 of Set 12 | roma
# Processing Record 43 of Set 12 | maragogi
# Processing Record 44 of Set 12 | kati
# Processing Record 45 of Set 12 | zheleznodorozhnyy
# Processing Record 46 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 47 of Set 12 | synya
# Processing Record 48 of Set 12 | scarborough
# Processing Record 49 of Set 12 | new glasgow
# Processing Record 50 of Set 12 | adrar
# Processing Record 1 of Set 13 | port keats
# Processing Record 2 of Set 13 | paranaiba
# Processing Record 3 of Set 13 | chulman
# Processing Record 4 of Set 13 | yurino
# Processing Record 5 of Set 13 | brooks
# Processing Record 6 of Set 13 | banda aceh
# Processing Record 7 of Set 13 | florence
# Processing Record 8 of Set 13 | sataua
# City not found. Skipping...
# Processing Record 9 of Set 13 | selikhino
# Processing Record 10 of Set 13 | port macquarie
# Processing Record 11 of Set 13 | tres arroyos
# Processing Record 12 of Set 13 | north branch
# Processing Record 13 of Set 13 | empangeni
# Processing Record 14 of Set 13 | huarmey
# Processing Record 15 of Set 13 | longlac
# City not found. Skipping...
# Processing Record 16 of Set 13 | daru
# Processing Record 17 of Set 13 | robe
# Processing Record 18 of Set 13 | ambanja
# Processing Record 19 of Set 13 | sambava
# Processing Record 20 of Set 13 | port shepstone
# Processing Record 21 of Set 13 | pirojpur
# Processing Record 22 of Set 13 | roald
# Processing Record 23 of Set 13 | vila franca do campo
# Processing Record 24 of Set 13 | honiara
# Processing Record 25 of Set 13 | verkh-usugli
# Processing Record 26 of Set 13 | loknya
# Processing Record 27 of Set 13 | mount pleasant
# Processing Record 28 of Set 13 | bucerias
# Processing Record 29 of Set 13 | yaan
# Processing Record 30 of Set 13 | balikpapan
# Processing Record 31 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 32 of Set 13 | neubrandenburg
# Processing Record 33 of Set 13 | achi
# Processing Record 34 of Set 13 | kargapolye
# City not found. Skipping...
# Processing Record 35 of Set 13 | dhidhdhoo
# Processing Record 36 of Set 13 | mount gambier
# Processing Record 37 of Set 13 | rio cuarto
# Processing Record 38 of Set 13 | southbridge
# Processing Record 39 of Set 13 | jand
# Processing Record 40 of Set 13 | carutapera
# Processing Record 41 of Set 13 | orodara
# Processing Record 42 of Set 13 | kidal
# Processing Record 43 of Set 13 | macusani
# Processing Record 44 of Set 13 | acajutla
# Processing Record 45 of Set 13 | aktas
# Processing Record 46 of Set 13 | laguna de perlas
# Processing Record 47 of Set 13 | watertown
# Processing Record 48 of Set 13 | clarence town
# Processing Record 49 of Set 13 | saquena
# Processing Record 50 of Set 13 | oildale
# Processing Record 1 of Set 14 | upata
# Processing Record 2 of Set 14 | fare
# Processing Record 3 of Set 14 | kashin
# Processing Record 4 of Set 14 | nara
# Processing Record 5 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 6 of Set 14 | calella
# Processing Record 7 of Set 14 | sinkat
# City not found. Skipping...
# Processing Record 8 of Set 14 | shimoda
# Processing Record 9 of Set 14 | goderich
# Processing Record 10 of Set 14 | fredericksburg
# Processing Record 11 of Set 14 | kawalu
# Processing Record 12 of Set 14 | san policarpo
# Processing Record 13 of Set 14 | strezhevoy
# Processing Record 14 of Set 14 | mayumba
# Processing Record 15 of Set 14 | batagay
# Processing Record 16 of Set 14 | senekal
# Processing Record 17 of Set 14 | macklin
# Processing Record 18 of Set 14 | caxito
# Processing Record 19 of Set 14 | traverse city
# Processing Record 20 of Set 14 | port hueneme
# Processing Record 21 of Set 14 | holme
# Processing Record 22 of Set 14 | zonguldak
# Processing Record 23 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 24 of Set 14 | molochnoye
# Processing Record 25 of Set 14 | pimentel
# Processing Record 26 of Set 14 | straumen
# Processing Record 27 of Set 14 | angra
# City not found. Skipping...
# Processing Record 28 of Set 14 | houston
# Processing Record 29 of Set 14 | aripuana
# Processing Record 30 of Set 14 | ziarat
# Processing Record 31 of Set 14 | bo rai
# Processing Record 32 of Set 14 | paita
# Processing Record 33 of Set 14 | rawson
# Processing Record 34 of Set 14 | kostomuksha
# Processing Record 35 of Set 14 | konevo
# Processing Record 36 of Set 14 | payakumbuh
# Processing Record 37 of Set 14 | anori
# Processing Record 38 of Set 14 | hit
# Processing Record 39 of Set 14 | maiduguri
# Processing Record 40 of Set 14 | dongsheng
# Processing Record 41 of Set 14 | astana
# Processing Record 42 of Set 14 | nizhniy ingash
# Processing Record 43 of Set 14 | laranjeiras do sul
# Processing Record 44 of Set 14 | maniitsoq
# Processing Record 45 of Set 14 | kultuk
# Processing Record 46 of Set 14 | dunedin
# Processing Record 47 of Set 14 | bastia
# Processing Record 48 of Set 14 | nikolsk
# Processing Record 49 of Set 14 | ibra
# Processing Record 50 of Set 14 | plouzane
# Processing Record 1 of Set 15 | berlevag
# Processing Record 2 of Set 15 | tevaitoa
# Processing Record 3 of Set 15 | senanga
# Processing Record 4 of Set 15 | doha
# Processing Record 5 of Set 15 | wahran
# City not found. Skipping...
# Processing Record 6 of Set 15 | afogados da ingazeira
# Processing Record 7 of Set 15 | wana
# Processing Record 8 of Set 15 | pitimbu
# Processing Record 9 of Set 15 | nichinan
# Processing Record 10 of Set 15 | camopi
# Processing Record 11 of Set 15 | ketchenery
# City not found. Skipping...
# Processing Record 12 of Set 15 | kapoeta
# Processing Record 13 of Set 15 | ormara
# Processing Record 14 of Set 15 | praia da vitoria
# Processing Record 15 of Set 15 | mbandaka
# Processing Record 16 of Set 15 | de haan
# Processing Record 17 of Set 15 | gaoua
# Processing Record 18 of Set 15 | torrington
# Processing Record 19 of Set 15 | matameye
# City not found. Skipping...
# Processing Record 20 of Set 15 | khandyga
# Processing Record 21 of Set 15 | acapulco
# Processing Record 22 of Set 15 | ruwi
# Processing Record 23 of Set 15 | teguldet
# Processing Record 24 of Set 15 | pinawa
# Processing Record 25 of Set 15 | ballstad
# City not found. Skipping...
# Processing Record 26 of Set 15 | petropavl
# Processing Record 27 of Set 15 | sulphur
# Processing Record 28 of Set 15 | khudumelapye
# Processing Record 29 of Set 15 | marfino
# Processing Record 30 of Set 15 | duncan
# Processing Record 31 of Set 15 | swan river
# Processing Record 32 of Set 15 | oktyabrskaya
# City not found. Skipping...
# Processing Record 33 of Set 15 | tyukalinsk
# Processing Record 34 of Set 15 | mount abu
# Processing Record 35 of Set 15 | zhigansk
# Processing Record 36 of Set 15 | vangaindrano
# Processing Record 37 of Set 15 | raduzhnyy
# Processing Record 38 of Set 15 | amuntai
# Processing Record 39 of Set 15 | ust-kulom
# Processing Record 40 of Set 15 | simbahan
# Processing Record 41 of Set 15 | norfolk
# Processing Record 42 of Set 15 | union city
# Processing Record 43 of Set 15 | salvador
# Processing Record 44 of Set 15 | yangjiang
# Processing Record 45 of Set 15 | milford
# Processing Record 46 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 47 of Set 15 | nurota
# Processing Record 48 of Set 15 | slave lake
# Processing Record 49 of Set 15 | alekseyevsk
# Processing Record 50 of Set 15 | kendari
# Processing Record 1 of Set 16 | tidore
# City not found. Skipping...
# Processing Record 2 of Set 16 | poyarkovo
# Processing Record 3 of Set 16 | alta floresta
# Processing Record 4 of Set 16 | remontnoye
# Processing Record 5 of Set 16 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 6 of Set 16 | itanagar
# Processing Record 7 of Set 16 | sri aman
# Processing Record 8 of Set 16 | jujuy
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
#print(city_data)
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Yellowknife  62.4560 -114.3525     -7.58        95         100
# 1     Alyangula -13.8483  136.4192     80.47        89          75
# 2        Kodiak  57.7900 -152.4072     26.11        68          40
# 3    Nikolskoye  59.7035   30.7861     27.39        95         100
# 4  Punta Arenas -53.1500  -70.9167     53.71        40          40
# 5        Albany  42.6001  -73.9662     21.74        38          13
# 6       Iquique -20.2208  -70.1431     73.44        69           2
# 7      Cherskiy  68.7500  161.3000    -26.73        98          99
# 8     Jamestown  42.0970  -79.2353     21.02        51         100
# 9  Snezhnogorsk  69.1933   33.2531      1.40        99          66
#
#    Wind Speed Country Current Description
# 0        6.91      CA          light snow
# 1        9.22      AU       broken clouds
# 2       14.97      US    scattered clouds
# 3        6.73      RU          light snow
# 4       28.77      CL    scattered clouds
# 5        1.99      US          few clouds
# 6        2.06      CL           clear sky
# 7        1.45      RU     overcast clouds
# 8        4.00      US     overcast clouds
# 9        8.86      RU       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
